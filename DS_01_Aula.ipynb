# %% [markdown]
# <a href="https://colab.research.google.com/github/lafigueiredo/Hello-World/blob/master/DS_01_Aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###LISTAS  encurtador.com.br/dkwxy

# %% [markdown]
# # Nova seção

# %%
#Listas

# %%
#matrizes

# %%
#CRIE UM DATA FRAME LIVRARIA 
#COM AS COLUNAS TITULO | AUTOR | PREÇO | ESTOQUE 
#CADASTRE 5 LIVROS

# %% [markdown]
# ###JOGADORES

# %%
#IMPORTAR O ARQUIVO CSV jogadores.csv import pandas as pd
import pandas as pd
jogadores = pd.read_csv('/content/jogadores.csv')
display(jogadores)

# %%
#3 primeiros registros 
display(jogadores.head(5))
# Out:
#         Nome completo do jogador  Altura em cm  Peso em kg  \
# 0  Neymar da Silva Santos Júnior          1.75          68
# 1       Ronaldo de Assis Moreira          1.82         100
# 2   Ronaldo Luís Nazário de Lima          1.82         130
# 3    Edson Arantes do Nascimento          1.73          80
# 4        Gabriel Barbosa Almeida          1.78          68
#
#   Time que o jogador participou  Data de nascimento do jogador  \
# 0                        Santos                           1992
# 1                        Grêmio                           1980
# 2                      Cruzeiro                           1976
# 3                         Bauru                           1940
# 4                  São Bernardo                           1996
#
#   Cidade onde o jogador nasceu. Estado onde o jogador nasceu
# 0               Mogi das Cruzes                    São Paulo
# 1                  Portp Alegre            Rio Grande do Sul
# ...

# %%
#número de linhas e colunas 
print(jogadores.shape)
# Out:
# (9, 7)

# %%
#descrição - describe
jogadores = pd.read_csv('/content/jogadores.csv')
jogadores_df = pd.DataFrame(jogadores)
display(jogadores_df.describe())

# %%
#Qual é a média de altura dos jogadores
jogadores['Altura em cm'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c07271650d8e> in <module>
#       1 #Qual é a média de altura dos jogadores
# ----> 2 jogadores['Altura em cm'].mean()
#
# NameError: name 'jogadores' is not defined

# %%
#Qual é a maior altura 
jogadores['Altura em cm'].max()

# %%
#Qual é a menor altura 
jogadores['Altura em cm'].min()

# %%
#Qual é o time que mais jogadores participaram
jogadores['Time que o jogador participou'].value_counts()
# Out:
# Cruzeiro        2
# Santos          1
# Grêmio          1
# Bauru           1
# São Bernardo    1
# Pau Grande      1
# Flamengo        1
# Palmeiras       1
# Name: Time que o jogador participou, dtype: int64

# %%
#Lista dos o jogadores do mais leve para o mais pesado 
jogadores.sort_values('Peso em kg')
# Out:
#         Nome completo do jogador  Altura em cm  Peso em kg  \
# 5      Eduardo Pereira Rodrigues          1.66          63
# 8     Ronielson da Silva Barbosa          1.67          65
# 0  Neymar da Silva Santos Júnior          1.75          68
# 4        Gabriel Barbosa Almeida          1.78          68
# 3    Edson Arantes do Nascimento          1.73          80
# 6    Manoel Francisco dos Santos          1.69          85
# 7         Arthur Antunes Coimbra          1.72          90
# 1       Ronaldo de Assis Moreira          1.82         100
# 2   Ronaldo Luís Nazário de Lima          1.82         130
#
#   Time que o jogador participou  Data de nascimento do jogador  \
# 5                      Cruzeiro                           1992
# 8                     Palmeiras                           1995
# 0                        Santos                           1992
# 4                  São Bernardo                           1996
# ...

# %%
#Qual é o jogador mais leve para o mais pesado
jogadores['IMC'] = jogadores['Peso em kg'] / jogadores['Altura em cm'] ** 2
display(jogadores)
# Out:
#         Nome completo do jogador  Altura em cm  Peso em kg  \
# 0  Neymar da Silva Santos Júnior          1.75          68
# 1       Ronaldo de Assis Moreira          1.82         100
# 2   Ronaldo Luís Nazário de Lima          1.82         130
# 3    Edson Arantes do Nascimento          1.73          80
# 4        Gabriel Barbosa Almeida          1.78          68
# 5      Eduardo Pereira Rodrigues          1.66          63
# 6    Manoel Francisco dos Santos          1.69          85
# 7         Arthur Antunes Coimbra          1.72          90
# 8     Ronielson da Silva Barbosa          1.67          65
#
#   Time que o jogador participou  Data de nascimento do jogador  \
# 0                        Santos                           1992
# 1                        Grêmio                           1980
# 2                      Cruzeiro                           1976
# 3                         Bauru                           1940
# ...

# %%
jogadores.loc[:,['Nome completo do jogador', 'IMC']]
# Out:
#         Nome completo do jogador        IMC
# 0  Neymar da Silva Santos Júnior  22.204082
# 1       Ronaldo de Assis Moreira  30.189591
# 2   Ronaldo Luís Nazário de Lima  39.246468
# 3    Edson Arantes do Nascimento  26.729927
# 4        Gabriel Barbosa Almeida  21.461937
# 5      Eduardo Pereira Rodrigues  22.862534
# 6    Manoel Francisco dos Santos  29.760863
# 7         Arthur Antunes Coimbra  30.421850
# 8     Ronielson da Silva Barbosa  23.306680
